# %% [markdown]
# This file is for grouping and merging all yellow, green, fhv and fhvhv data.
#
# This file calculates the sum of passengers picked up and dropped off each hour in each location for each transport type and adds the two together.
#
# It then merges the data and gets the sum again by hour and location. This operation is done twice as there's not enough RAM on my PC to load the datasets at the same time.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq
import os

# %%
parquet_files = ["all_yellow_tripdata_cleaned.parquet", "all_green_tripdata_cleaned.parquet", "all_fhv_tripdata_cleaned.parquet"] + [f"all_fhvhv_tripdata_cleaned_{i}.parquet" for i in range(20)]

# %%
for parquet_file in parquet_files:
    print("grouping and merging", parquet_file)
    # Read in file
    parquet_reader = pq.ParquetFile(parquet_file)
    table = pq.read_table(parquet_file)
    df = table.to_pandas()
    
    print(df.columns)

    df['pickup_datetime'] = df['pickup_datetime'].dt.floor(freq='h')
    df['dropoff_datetime'] = df['dropoff_datetime'].dt.floor(freq='h')

    # Get sum of passengers by hour by pickup location
    df_pickup = pd.DataFrame(df.groupby(['pickup_datetime', 'pickup_loc'])['passenger_count'].sum().reset_index())
    col_names = {
        "pickup_datetime": "datetime",
        "pickup_loc": "location"
    }
    df_pickup.rename(columns=col_names, inplace=True)

    # Get sum of passengers by hour by dropoff location
    df_dropoff = pd.DataFrame(df.groupby(['dropoff_datetime', 'dropoff_loc'])['passenger_count'].sum().reset_index())
    col_names = {
        "dropoff_datetime": "datetime",
        "dropoff_loc": "location"
    }

    df_dropoff.rename(columns=col_names, inplace=True)

    # Concatenate dfs
    merged_df = pd.concat([df_pickup,df_dropoff])
    merged_df.dropna(inplace=True)
    merged_df['location'] = merged_df['location'].astype('int64')


    merged_df.to_parquet(f"{parquet_file[:-8]}_grouped.parquet")
    print(merged_df.shape)
# Out:
# grouping and merging all_yellow_tripdata_cleaned.parquet
# Index(['pickup_datetime', 'dropoff_datetime', 'pickup_loc', 'dropoff_loc',
#        'passenger_count'],
#       dtype='object')
# (7386549, 3)
# grouping and merging all_green_tripdata_cleaned.parquet
# Index(['pickup_datetime', 'dropoff_datetime', 'pickup_loc', 'dropoff_loc',
#        'passenger_count'],
#       dtype='object')
# (2015761, 3)
# grouping and merging all_fhv_tripdata_cleaned.parquet
# Index(['pickup_datetime', 'dropoff_datetime', 'pickup_loc', 'dropoff_loc',
#        'passenger_count'],
#       dtype='object')
# (9054343, 3)
# grouping and merging all_fhvhv_tripdata_cleaned_0.parquet
# Index(['pickup_datetime', 'dropoff_datetime', 'pickup_loc', 'dropoff_loc',
#        'passenger_count'],
#       dtype='object')
# (1013577, 3)
# grouping and merging all_fhvhv_tripdata_cleaned_1.parquet
# Index(['pickup_datetime', 'dropoff_datetime', 'pickup_loc', 'dropoff_loc',
#        'passenger_count'],
#       dtype='object')
# (884805, 3)
# grouping and merging all_fhvhv_tripdata_cleaned_2.parquet
# Index(['pickup_datetime', 'dropoff_datetime', 'pickup_loc', 'dropoff_loc',
#        'passenger_count'],
#       dtype='object')
# (908140, 3)
# grouping and merging all_fhvhv_tripdata_cleaned_3.parquet
# Index(['pickup_datetime', 'dropoff_datetime', 'pickup_loc', 'dropoff_loc',
#        'passenger_count'],
#       dtype='object')
# (858690, 3)
# grouping and merging all_fhvhv_tripdata_cleaned_4.parquet
# Index(['pickup_datetime', 'dropoff_datetime', 'pickup_loc', 'dropoff_loc',
#        'passenger_count'],
#       dtype='object')
# (841309, 3)
# grouping and merging all_fhvhv_tripdata_cleaned_5.parquet
# Index(['pickup_datetime', 'dropoff_datetime', 'pickup_loc', 'dropoff_loc',
#        'passenger_count'],
#       dtype='object')
# (767785, 3)
# grouping and merging all_fhvhv_tripdata_cleaned_6.parquet
# Index(['pickup_datetime', 'dropoff_datetime', 'pickup_loc', 'dropoff_loc',
#        'passenger_count'],
#       dtype='object')
# (746238, 3)
# grouping and merging all_fhvhv_tripdata_cleaned_7.parquet
# Index(['pickup_datetime', 'dropoff_datetime', 'pickup_loc', 'dropoff_loc',
#        'passenger_count'],
#       dtype='object')
# (777373, 3)
# grouping and merging all_fhvhv_tripdata_cleaned_8.parquet
# Index(['pickup_datetime', 'dropoff_datetime', 'pickup_loc', 'dropoff_loc',
#        'passenger_count'],
#       dtype='object')
# (756964, 3)
# grouping and merging all_fhvhv_tripdata_cleaned_9.parquet
# Index(['pickup_datetime', 'dropoff_datetime', 'pickup_loc', 'dropoff_loc',
#        'passenger_count'],
#       dtype='object')
# (736774, 3)
# grouping and merging all_fhvhv_tripdata_cleaned_10.parquet
# Index(['pickup_datetime', 'dropoff_datetime', 'pickup_loc', 'dropoff_loc',
#        'passenger_count'],
#       dtype='object')
# (711546, 3)
# grouping and merging all_fhvhv_tripdata_cleaned_11.parquet
# Index(['pickup_datetime', 'dropoff_datetime', 'pickup_loc', 'dropoff_loc',
#        'passenger_count'],
#       dtype='object')
# (668503, 3)
# grouping and merging all_fhvhv_tripdata_cleaned_12.parquet
# Index(['pickup_datetime', 'dropoff_datetime', 'pickup_loc', 'dropoff_loc',
#        'passenger_count'],
#       dtype='object')
# (683706, 3)
# grouping and merging all_fhvhv_tripdata_cleaned_13.parquet
# Index(['pickup_datetime', 'dropoff_datetime', 'pickup_loc', 'dropoff_loc',
#        'passenger_count'],
#       dtype='object')
# (681961, 3)
# grouping and merging all_fhvhv_tripdata_cleaned_14.parquet
# Index(['pickup_datetime', 'dropoff_datetime', 'pickup_loc', 'dropoff_loc',
#        'passenger_count'],
#       dtype='object')
# (746492, 3)
# grouping and merging all_fhvhv_tripdata_cleaned_15.parquet
# Index(['pickup_datetime', 'dropoff_datetime', 'pickup_loc', 'dropoff_loc',
#        'passenger_count'],
#       dtype='object')
# (673510, 3)
# grouping and merging all_fhvhv_tripdata_cleaned_16.parquet
# Index(['pickup_datetime', 'dropoff_datetime', 'pickup_loc', 'dropoff_loc',
#        'passenger_count'],
#       dtype='object')
# (635315, 3)
# grouping and merging all_fhvhv_tripdata_cleaned_17.parquet
# Index(['pickup_datetime', 'dropoff_datetime', 'pickup_loc', 'dropoff_loc',
#        'passenger_count'],
#       dtype='object')
# (712462, 3)
# grouping and merging all_fhvhv_tripdata_cleaned_18.parquet
# Index(['pickup_datetime', 'dropoff_datetime', 'pickup_loc', 'dropoff_loc',
#        'passenger_count'],
#       dtype='object')
# (631235, 3)
# grouping and merging all_fhvhv_tripdata_cleaned_19.parquet
# Index(['pickup_datetime', 'dropoff_datetime', 'pickup_loc', 'dropoff_loc',
#        'passenger_count'],
#       dtype='object')
# (684572, 3)

# %%
grouped_files = [f"{parquet_file[:-8]}_grouped.parquet" for parquet_file in parquet_files]

combined_df = pd.DataFrame()
for grouped_file in grouped_files:
    parquet_reader = pq.ParquetFile(grouped_file)
    table = pq.read_table(grouped_file)
    df = table.to_pandas()

    df.dropna(inplace=True)
    print(df.dtypes)

    combined_df = pd.concat([combined_df, df])

    combined_df = pd.DataFrame(combined_df.groupby(['datetime', 'location'])['passenger_count'].sum().reset_index())
    print(combined_df.head())
    print(combined_df.shape)
# Out:
# datetime           datetime64[us]
# location                    int64
# passenger_count             int64
# dtype: object
#     datetime  location  passenger_count
# 0 2021-01-01         4               11
# 1 2021-01-01         7                4
# 2 2021-01-01        11                1
# 3 2021-01-01        13                5
# 4 2021-01-01        17                3
# (4828648, 3)
# datetime           datetime64[us]
# location                    int64
# passenger_count             int64
# dtype: object
#     datetime  location  passenger_count
# 0 2021-01-01         4               11
# 1 2021-01-01         7                9
# 2 2021-01-01        11                1
# 3 2021-01-01        13                5
# 4 2021-01-01        17                4
# (5012259, 3)
# datetime           datetime64[us]
# location                    int64
# passenger_count             int64
# dtype: object
#     datetime  location  passenger_count
# 0 2021-01-01         3                4
# 1 2021-01-01         4               11
# 2 2021-01-01         7               10
# 3 2021-01-01        10                5
# 4 2021-01-01        11                1
# (6858625, 3)
# datetime           datetime64[us]
# location                    int64
# passenger_count             int64
# dtype: object
#     datetime  location  passenger_count
# 0 2021-01-01         3              132
# 1 2021-01-01         4              234
# 2 2021-01-01         5               19
# 3 2021-01-01         6               37
# 4 2021-01-01         7              493
# (6928488, 3)
# datetime           datetime64[us]
# location                    int64
# passenger_count             int64
# dtype: object
#     datetime  location  passenger_count
# 0 2021-01-01         3              132
# 1 2021-01-01         4              234
# 2 2021-01-01         5               19
# 3 2021-01-01         6               37
# 4 2021-01-01         7              493
# (6976287, 3)
# datetime           datetime64[us]
# location                    int64
# passenger_count             int64
# dtype: object
#     datetime  location  passenger_count
# 0 2021-01-01         3              132
# 1 2021-01-01         4              234
# 2 2021-01-01         5               19
# 3 2021-01-01         6               37
# 4 2021-01-01         7              493
# (7019956, 3)
# datetime           datetime64[us]
# location                    int64
# passenger_count             int64
# dtype: object
#     datetime  location  passenger_count
# 0 2021-01-01         3              132
# 1 2021-01-01         4              234
# 2 2021-01-01         5               19
# 3 2021-01-01         6               37
# 4 2021-01-01         7              493
# (7063070, 3)
# datetime           datetime64[us]
# location                    int64
# passenger_count             int64
# dtype: object
#     datetime  location  passenger_count
# 0 2021-01-01         3              132
# 1 2021-01-01         4              234
# 2 2021-01-01         5               19
# 3 2021-01-01         6               37
# 4 2021-01-01         7              493
# (7104682, 3)
# datetime           datetime64[us]
# location                    int64
# passenger_count             int64
# dtype: object
#     datetime  location  passenger_count
# 0 2021-01-01         3              132
# 1 2021-01-01         4              234
# 2 2021-01-01         5               19
# 3 2021-01-01         6               37
# 4 2021-01-01         7              493
# (7144602, 3)
# datetime           datetime64[us]
# location                    int64
# passenger_count             int64
# dtype: object
#     datetime  location  passenger_count
# 0 2021-01-01         3              132
# 1 2021-01-01         4              234
# 2 2021-01-01         5               19
# 3 2021-01-01         6               37
# 4 2021-01-01         7              493
# (7180060, 3)
# datetime           datetime64[us]
# location                    int64
# passenger_count             int64
# dtype: object
#     datetime  location  passenger_count
# 0 2021-01-01         3              132
# 1 2021-01-01         4              234
# 2 2021-01-01         5               19
# 3 2021-01-01         6               37
# 4 2021-01-01         7              493
# (7214948, 3)
# datetime           datetime64[us]
# location                    int64
# passenger_count             int64
# dtype: object
#     datetime  location  passenger_count
# 0 2021-01-01         3              132
# 1 2021-01-01         4              234
# 2 2021-01-01         5               19
# 3 2021-01-01         6               37
# 4 2021-01-01         7              493
# (7251025, 3)
# datetime           datetime64[us]
# location                    int64
# passenger_count             int64
# dtype: object
#     datetime  location  passenger_count
# 0 2021-01-01         3              132
# 1 2021-01-01         4              234
# 2 2021-01-01         5               19
# 3 2021-01-01         6               37
# 4 2021-01-01         7              493
# (7288681, 3)
# datetime           datetime64[us]
# location                    int64
# passenger_count             int64
# dtype: object
#     datetime  location  passenger_count
# 0 2021-01-01         3              132
# 1 2021-01-01         4              234
# 2 2021-01-01         5               19
# 3 2021-01-01         6               37
# 4 2021-01-01         7              493
# (7325417, 3)
# datetime           datetime64[us]
# location                    int64
# passenger_count             int64
# dtype: object
#     datetime  location  passenger_count
# 0 2021-01-01         3              132
# 1 2021-01-01         4              234
# 2 2021-01-01         5               19
# 3 2021-01-01         6               37
# 4 2021-01-01         7              493
# (7361004, 3)
# datetime           datetime64[us]
# location                    int64
# passenger_count             int64
# dtype: object
#     datetime  location  passenger_count
# 0 2021-01-01         3              132
# 1 2021-01-01         4              234
# 2 2021-01-01         5               19
# 3 2021-01-01         6               37
# 4 2021-01-01         7              493
# (7394114, 3)
# datetime           datetime64[us]
# location                    int64
# passenger_count             int64
# dtype: object
#     datetime  location  passenger_count
# 0 2021-01-01         3              132
# 1 2021-01-01         4              234
# 2 2021-01-01         5               19
# 3 2021-01-01         6               37
# 4 2021-01-01         7              493
# (7424380, 3)
# datetime           datetime64[us]
# location                    int64
# passenger_count             int64
# dtype: object
#     datetime  location  passenger_count
# 0 2021-01-01         3              132
# 1 2021-01-01         4              234
# 2 2021-01-01         5               19
# 3 2021-01-01         6               37
# 4 2021-01-01         7              493
# (7455683, 3)
# datetime           datetime64[us]
# location                    int64
# passenger_count             int64
# dtype: object
#     datetime  location  passenger_count
# 0 2021-01-01         3              132
# 1 2021-01-01         4              234
# 2 2021-01-01         5               19
# 3 2021-01-01         6               37
# 4 2021-01-01         7              493
# (7484704, 3)
# datetime           datetime64[us]
# location                    int64
# passenger_count             int64
# dtype: object
#     datetime  location  passenger_count
# 0 2021-01-01         3              132
# 1 2021-01-01         4              234
# 2 2021-01-01         5               19
# 3 2021-01-01         6               37
# 4 2021-01-01         7              493
# (7513233, 3)
# datetime           datetime64[us]
# location                    int64
# passenger_count             int64
# dtype: object
#     datetime  location  passenger_count
# 0 2021-01-01         3              132
# 1 2021-01-01         4              234
# 2 2021-01-01         5               19
# 3 2021-01-01         6               37
# 4 2021-01-01         7              493
# (7548555, 3)
# datetime           datetime64[us]
# location                    int64
# passenger_count             int64
# dtype: object
#     datetime  location  passenger_count
# 0 2021-01-01         3              132
# 1 2021-01-01         4              234
# 2 2021-01-01         5               19
# 3 2021-01-01         6               37
# 4 2021-01-01         7              493
# (7584400, 3)
# datetime           datetime64[us]
# location                    int64
# passenger_count             int64
# dtype: object
#     datetime  location  passenger_count
# 0 2021-01-01         3              132
# 1 2021-01-01         4              234
# 2 2021-01-01         5               19
# 3 2021-01-01         6               37
# 4 2021-01-01         7              493
# (7696641, 3)

# %%
combined_df[combined_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [datetime, location, passenger_count]
# Index: []

# %%
combined_df['datetime'].nunique()
# Out:
# 29929

# %%
combined_df['location'].nunique()
# Out:
# 265

# %%
combined_df.to_parquet("all_tlc_data_cleaned.parquet", engine='pyarrow', index=False)

# %%
combined_df.to_csv("all_tlc_data_cleaned.csv", index=False)
